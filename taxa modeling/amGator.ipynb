# %%
import pandas as pd
import numpy as np

# supress future warnings
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

import model as model

# %%
# python_df = pd.read_csv('../data/PYTHON.csv')
AmGator_df = pd.read_csv('../data/ALLIGATOR.csv')
# BEagle_df = pd.read_csv('../data/HALIAEETUS.csv')

# %%
AmGator_df.head()
# Out:
#    control_number species_code      genus           species wildlf_desc  \
# 0      2018327962         ALLM  ALLIGATOR  MISSISSIPPIENSIS         SPE
# 1      2018328260         ALLM  ALLIGATOR  MISSISSIPPIENSIS         SPE
# 2      2018328391         ALLM  ALLIGATOR  MISSISSIPPIENSIS         LPS
# 3      2018328646         ALLM  ALLIGATOR  MISSISSIPPIENSIS         SPE
# 4      2018328840         ALLM  ALLIGATOR  MISSISSIPPIENSIS         SPE
#
#   wildlf_cat cartons    qty unit    value  ... pt_cd specific_generic_name  \
# 0        REP    10.0  298.0   NO  16675.0  ...    MI    AMERICAN ALLIGATOR
# 1        REP    10.0  362.0   NO  22006.0  ...    MI    AMERICAN ALLIGATOR
# 2        REP     1.0    1.0   NO    212.0  ...    DF    AMERICAN ALLIGATOR
# 3        REP     1.0   11.0   NO    755.0  ...    MI    AMERICAN ALLIGATOR
# 4        REP    74.0  168.0   NO  29860.0  ...    MI    AMERICAN ALLIGATOR
#
#   unit_NO unit_KG unit_LT unit_MT unit_M2 qty_new ship_date_yyyy ship_date_mm
# 0    True   False   False   False   False   298.0           2018            4
# 1    True   False   False   False   False   362.0           2018            4
# 2    True   False   False   False   False     1.0           2018            4
# 3    True   False   False   False   False    11.0           2018            4
# 4    True   False   False   False   False   168.0           2018            4
#
# [5 rows x 30 columns]

# %%
for trade_type_import in [True, False]:
    model.run_models(AmGator_df, imp=trade_type_import, genus_prefix ='amGator')
# Out:
# >>>>>> Begin model training for amGator I <<<<<<<<
# number of records in df: 69846
# number of records in df after trade type I filtering: 51984
# number of refused records in df: 854, 0.02%
#
# -------- training LogRegression classifer ----------
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 1e-07, 'clf__class_weight': 'balanced', 'clf__solver': 'liblinear'}
# Grid best score (recall):  0.661421996124031
# recall score on holdout: 0.6995305164319249
# model training time: 0:00:44.941183
#
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 0.1, 'clf__class_weight': None, 'clf__solver': 'lbfgs'}
# Grid best score (recall):  0.6130208333333333
# recall score on holdout: 0.6056338028169014
# SMOTE model training time: 0:00:49.637057
#
# -------- training DecisionTree classifer ----------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 6}
# Grid best score (recall):  0.6052446705426358
# recall score on holdout: 0.647887323943662
# model training time: 0:00:32.836601
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': None, 'clf__max_depth': 2}
# Grid best score (recall):  0.5445251937984497
# recall score on holdout: 0.5023474178403756
# SMOTE model training time: 0:00:44.995738
#
# -------- training RandomForest classifer ----------
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 3, 'clf__n_estimators': 30}
# Grid best score (recall):  0.6302325581395349
# recall score on holdout: 0.6666666666666666
# model training time: 0:05:58.644820
#
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 3, 'clf__n_estimators': 10}
# Grid best score (recall):  0.5880450581395349
# recall score on holdout: 0.6197183098591549
# SMOTE model training time: 0:11:19.548884
#
# -------- training GradientBoostingClassifier ----------
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 10, 'clf__loss': 'log_loss', 'clf__max_depth': 4, 'clf__n_estimators': 4}
# Grid best score (recall):  0.8005813953488372
# recall score on holdout: 0.8215962441314554
# model training time: 0:13:33.456200
#
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 0.01, 'clf__loss': 'log_loss', 'clf__max_depth': 4, 'clf__n_estimators': 50}
# Grid best score (recall):  0.5084544573643411
# recall score on holdout: 0.539906103286385
# SMOTE model training time: 0:46:11.728254
#
# -------- training XGBoostingClassifier ----------
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.3, 'clf__eval_metric': 'logloss', 'clf__gamma': 0.1, 'clf__max_depth': 6, 'clf__n_estimators': 100}
# Grid best score (recall):  0.26203972868217057
# recall score on holdout: 0.29107981220657275
# model training time: 0:55:50.367773
#
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.001, 'clf__eval_metric': 'logloss', 'clf__gamma': 0, 'clf__max_depth': 4, 'clf__n_estimators': 50}
# Grid best score (recall):  0.4865673449612403
# recall score on holdout: 0.539906103286385
# SMOTE model training time: 0:55:10.106329
#
#
# >>>>>> Begin model training for amGator E <<<<<<<<
# number of records in df: 69846
# number of records in df after trade type E filtering: 17861
# number of refused records in df: 109, 0.01%
#
# -------- training LogRegression classifer ----------
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 1e-07, 'clf__class_weight': 'balanced', 'clf__solver': 'liblinear'}
# Grid best score (recall):  0.7919117647058822
# recall score on holdout: 0.6666666666666666
# model training time: 0:00:20.419616
#
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 0.1, 'clf__class_weight': None, 'clf__solver': 'lbfgs'}
# Grid best score (recall):  0.6316176470588235
# recall score on holdout: 0.5555555555555556
# SMOTE model training time: 0:00:22.125284
#
# -------- training DecisionTree classifer ----------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 4}
# Grid best score (recall):  0.6720588235294118
# recall score on holdout: 0.5925925925925926
# model training time: 0:00:14.066663
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': None, 'clf__max_depth': 2}
# Grid best score (recall):  0.6838235294117647
# recall score on holdout: 0.6666666666666666
# SMOTE model training time: 0:00:18.406148
#
# -------- training RandomForest classifer ----------
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 3, 'clf__n_estimators': 4}
# Grid best score (recall):  0.6838235294117647
# recall score on holdout: 0.48148148148148145
# model training time: 0:02:18.783522
#
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 3, 'clf__n_estimators': 8}
# Grid best score (recall):  0.5852941176470587
# recall score on holdout: 0.6296296296296297
# SMOTE model training time: 0:04:06.526113
#
# -------- training GradientBoostingClassifier ----------
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 10, 'clf__loss': 'log_loss', 'clf__max_depth': 4, 'clf__n_estimators': 4}
# Grid best score (recall):  0.9036764705882353
# recall score on holdout: 0.8888888888888888
# model training time: 0:03:57.799457
#
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 10, 'clf__loss': 'log_loss', 'clf__max_depth': 6, 'clf__n_estimators': 10}
# Grid best score (recall):  0.6235294117647059
# recall score on holdout: 0.6666666666666666
# SMOTE model training time: 0:14:56.958839
#
# -------- training XGBoostingClassifier ----------
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.3, 'clf__eval_metric': 'logloss', 'clf__gamma': 0, 'clf__max_depth': 8, 'clf__n_estimators': 4}
# Grid best score (recall):  0.3536764705882353
# recall score on holdout: 0.25925925925925924
# model training time: 0:09:49.748163
#
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.3, 'clf__eval_metric': 'logloss', 'clf__gamma': 10, 'clf__max_depth': 4, 'clf__n_estimators': 10}
# Grid best score (recall):  0.538235294117647
# recall score on holdout: 0.4444444444444444
# SMOTE model training time: 0:21:09.450892
