# %%
import pandas as pd
import numpy as np
import taxamodelinghelper as helper
import joblib
import evaluate as evl

#set up random seed
rng = 42

# %%
python_df = pd.read_csv('../data/PYTHON.csv')
AmGator_df = pd.read_csv('../data/ALLIGATOR.csv')
BEagle_df = pd.read_csv('../data/HALIAEETUS.csv')

# %%
# best import 
import_path = 'Python_I_lr_pipe.joblib'
pipe = joblib.load(import_path)

# %%
evl.subgroup_eval(python_df, 'I', pipe , 'python')
# Out:
# python recall score on I holdout: 0.7445652173913043

# %%
evl.plot_LogReg_feature_importance(pipe)

# %%
# best export 
export_path = 'Python_E_lr_pipe.joblib'
pipe = joblib.load(export_path)
evl.subgroup_eval(python_df, 'E', pipe , 'python')
# Out:
# python recall score on E holdout: 0.7

# %%
evl.plot_LogReg_feature_importance(pipe)

# %%
# 2nd best import
import_path = 'Python_I_dt_pipe.joblib'
pipe = joblib.load(import_path)
evl.subgroup_eval(python_df, 'I', pipe , 'python')
# Out:
# python recall score on I holdout: 0.75

# %%
evl.plot_tree_importance('python', 'I', pipe, 'DecisionTree', 'dt')
