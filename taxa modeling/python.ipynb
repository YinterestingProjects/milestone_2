# %%
import pandas as pd
import numpy as np

# supress future warnings
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

import model as model

# %%
python_df = pd.read_csv('../data/PYTHON.csv')
# AmGator_df = pd.read_csv('../data/ALLIGATOR.csv')
# BEagle_df = pd.read_csv('../data/HALIAEETUS.csv')

# %%
python_df.head()
# Out:
#    control_number species_code   genus      species wildlf_desc wildlf_cat  \
# 0      2018330028         PYTM  PYTHON   BIVITTATUS         LPS        REP
# 1      2018330481         PYTM  PYTHON   BIVITTATUS         TRI        REP
# 2      2018330493         PYTM  PYTHON   BIVITTATUS         TRI        REP
# 3      2018330514         PYTR  PYTHON  RETICULATUS         LPS        REP
# 4      2018330514         PYTM  PYTHON   BIVITTATUS         TRI        REP
#
#   cartons  qty unit   value  ... pt_cd specific_generic_name unit_NO unit_KG  \
# 0     1.0  1.0   NO  4194.0  ...    NY        BURMESE PYTHON    True   False
# 1     3.0  3.0   NO   465.0  ...    NW        BURMESE PYTHON    True   False
# 2     2.0  2.0   NO   310.0  ...    NW        BURMESE PYTHON    True   False
# 3     6.0  1.0   NO   765.0  ...    NW    RETICULATED PYTHON    True   False
# 4     6.0  4.0   NO   620.0  ...    NW        BURMESE PYTHON    True   False
#
#   unit_LT unit_MT unit_M2 qty_new ship_date_yyyy ship_date_mm
# 0   False   False   False     1.0           2018            4
# 1   False   False   False     3.0           2018            4
# 2   False   False   False     2.0           2018            4
# 3   False   False   False     1.0           2018            4
# 4   False   False   False     4.0           2018            4
#
# [5 rows x 30 columns]

# %%
for trade_type_import in [True, False]:
    model.run_models(python_df, imp=trade_type_import, genus_prefix ='Python')
# Out:
# >>>>>> Begin model training for Python I <<<<<<<<
# number of records in df: 31985
# number of records in df after trade type I filtering: 29720
# number of refused records in df: 738, 0.02%
#
# -------- training LogRegression classifer ----------
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 1e-07, 'clf__class_weight': 'balanced', 'clf__solver': 'liblinear'}
# Grid best score (recall):  0.7651924651924652
# recall score on holdout: 0.7445652173913043
# model training time: 0:00:29.004345
#
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 0.1, 'clf__class_weight': None, 'clf__solver': 'lbfgs'}
# Grid best score (recall):  0.6514823914823914
# recall score on holdout: 0.6195652173913043
# SMOTE model training time: 0:00:31.367276
#
# -------- training DecisionTree classifer ----------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 4}
# Grid best score (recall):  0.7147256347256347
# recall score on holdout: 0.75
# model training time: 0:00:20.865522
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': None, 'clf__max_depth': 2}
# Grid best score (recall):  0.657051597051597
# recall score on holdout: 0.6739130434782609
# SMOTE model training time: 0:00:29.890636
#
# -------- training RandomForest classifer ----------
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 4, 'clf__n_estimators': 30}
# Grid best score (recall):  0.7002948402948402
# recall score on holdout: 0.6793478260869565
# model training time: 0:03:50.546323
#
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 4, 'clf__n_estimators': 10}
# Grid best score (recall):  0.6695331695331695
# recall score on holdout: 0.625
# SMOTE model training time: 0:07:59.266025
#
# -------- training GradientBoostingClassifier ----------
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 10, 'clf__loss': 'log_loss', 'clf__max_depth': 8, 'clf__n_estimators': 4}
# Grid best score (recall):  0.7238165438165438
# recall score on holdout: 0.5760869565217391
# model training time: 0:08:22.832910
#
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 10, 'clf__loss': 'log_loss', 'clf__max_depth': 6, 'clf__n_estimators': 10}
# Grid best score (recall):  0.6158394758394758
# recall score on holdout: 0.45652173913043476
# SMOTE model training time: 0:32:49.581187
#
# -------- training XGBoostingClassifier ----------
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.001, 'clf__eval_metric': 'logloss', 'clf__gamma': 0, 'clf__max_depth': 10, 'clf__n_estimators': 100}
# Grid best score (recall):  0.508943488943489
# recall score on holdout: 0.44021739130434784
# model training time: 0:18:45.478370
#
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.001, 'clf__eval_metric': 'logloss', 'clf__gamma': 0, 'clf__max_depth': 4, 'clf__n_estimators': 4}
# Grid best score (recall):  0.6155446355446356
# recall score on holdout: 0.532608695652174
# SMOTE model training time: 0:59:06.644883
#
#
# >>>>>> Begin model training for Python E <<<<<<<<
# number of records in df: 31985
# number of records in df after trade type E filtering: 2265
# number of refused records in df: 40, 0.02%
#
# -------- training LogRegression classifer ----------
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 1e-07, 'clf__class_weight': 'balanced', 'clf__solver': 'lbfgs'}
# Grid best score (recall):  0.8333333333333333
# recall score on holdout: 0.7
# model training time: 0:00:11.214056
#
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 0.1, 'clf__class_weight': None, 'clf__solver': 'lbfgs'}
# Grid best score (recall):  0.5666666666666667
# recall score on holdout: 0.6
# SMOTE model training time: 0:00:10.367528
#
# -------- training DecisionTree classifer ----------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': None, 'clf__max_depth': 6}
# Grid best score (recall):  0.5333333333333333
# recall score on holdout: 0.2
# model training time: 0:00:06.424719
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': None, 'clf__max_depth': 2}
# Grid best score (recall):  0.5666666666666667
# recall score on holdout: 0.5
# SMOTE model training time: 0:00:07.129227
#
# -------- training RandomForest classifer ----------
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 3, 'clf__n_estimators': 30}
# Grid best score (recall):  0.6333333333333332
# recall score on holdout: 0.6
# model training time: 0:00:59.182797
#
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 4, 'clf__n_estimators': 6}
# Grid best score (recall):  0.6
# recall score on holdout: 0.5
# SMOTE model training time: 0:01:14.731849
#
# -------- training GradientBoostingClassifier ----------
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 10, 'clf__loss': 'log_loss', 'clf__max_depth': 4, 'clf__n_estimators': 4}
# Grid best score (recall):  0.6666666666666666
# recall score on holdout: 1.0
# model training time: 0:00:49.335530
#
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 10, 'clf__loss': 'log_loss', 'clf__max_depth': 6, 'clf__n_estimators': 10}
# Grid best score (recall):  0.6666666666666667
# recall score on holdout: 0.4
# SMOTE model training time: 0:02:10.860000
#
# -------- training XGBoostingClassifier ----------
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.1, 'clf__eval_metric': 'logloss', 'clf__gamma': 0, 'clf__max_depth': 4, 'clf__n_estimators': 4}
# Grid best score (recall):  0.4666666666666666
# recall score on holdout: 0.2
# model training time: 0:12:59.524138
#
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.1, 'clf__eval_metric': 'logloss', 'clf__gamma': 0, 'clf__max_depth': 4, 'clf__n_estimators': 100}
# Grid best score (recall):  0.5666666666666667
# recall score on holdout: 0.3
# SMOTE model training time: 0:16:53.933116
