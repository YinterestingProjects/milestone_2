# %%
import pandas as pd
import numpy as np

# supress future warnings
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

import model as model

# %%
BEagle_df = pd.read_csv('../data/HALIAEETUS.csv')

# %%
BEagle_df.head()
# Out:
#    control_number species_code       genus        species wildlf_desc  \
# 0      2018311221         BAEA  HALIAEETUS  LEUCOCEPHALUS         FEA
# 1      2018311221         BAEA  HALIAEETUS  LEUCOCEPHALUS         FEA
# 2      2018347638         BAEA  HALIAEETUS  LEUCOCEPHALUS         FEA
# 3      2018357841         BAEA  HALIAEETUS  LEUCOCEPHALUS         FEA
# 4      2018359877         BAEA  HALIAEETUS  LEUCOCEPHALUS         FEA
#
#   wildlf_cat      cartons   qty unit  value  ... pt_cd specific_generic_name  \
# 0        EGL  NaN_cartons   2.0   NO    0.0  ...    NG            BALD EAGLE
# 1        EGL  NaN_cartons   1.0   NO    0.0  ...    NG            BALD EAGLE
# 2        EGL  NaN_cartons  10.0   NO    0.0  ...     6            BALD EAGLE
# 3        EGL          0.0   1.0   NO   36.0  ...    CH            BALD EAGLE
# 4        EGL          1.0  25.0   NO    0.0  ...    CH            BALD EAGLE
#
#   unit_NO unit_KG unit_LT unit_MT unit_M2 qty_new ship_date_yyyy ship_date_mm
# 0    True   False   False   False   False     2.0           2018            6
# 1    True   False   False   False   False     1.0           2018            6
# 2    True   False   False   False   False    10.0           2018            4
# 3    True   False   False   False   False     1.0           2018            5
# 4    True   False   False   False   False    25.0           2018            5
#
# [5 rows x 30 columns]

# %%
for trade_type_import in [True, False]:
    model.run_models(BEagle_df, imp=trade_type_import, genus_prefix ='baldEagle')
# Out:
# >>>>>> Begin model training for baldEagle I <<<<<<<<
# number of records in df: 547
# number of records in df after trade type I filtering: 518
# number of refused records in df: 59, 0.11%
#
# -------- training LogRegression classifer ----------
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 1e-07, 'clf__class_weight': 'balanced', 'clf__solver': 'lbfgs'}
# Grid best score (recall):  0.9527777777777778
# recall score on holdout: 0.8666666666666667
# model training time: 0:00:07.484481
#
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Grid best parameter (max. recall):  {'clf__C': 0.001, 'clf__class_weight': None, 'clf__solver': 'lbfgs'}
# Grid best score (recall):  0.8833333333333332
# recall score on holdout: 0.7333333333333333
# SMOTE model training time: 0:00:08.019182
#
# -------- training DecisionTree classifer ----------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 2}
# Grid best score (recall):  0.9305555555555556
# recall score on holdout: 0.7333333333333333
# model training time: 0:00:05.397031
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Grid best parameter (max. recall):  {'clf__class_weight': None, 'clf__max_depth': 3}
# Grid best score (recall):  0.9083333333333332
# recall score on holdout: 0.7333333333333333
# SMOTE model training time: 0:00:05.461165
#
# -------- training RandomForest classifer ----------
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 3, 'clf__n_estimators': 10}
# Grid best score (recall):  0.9305555555555556
# recall score on holdout: 0.7333333333333333
# model training time: 0:00:47.294355
#
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# Grid best parameter (max. recall):  {'clf__class_weight': 'balanced', 'clf__max_depth': 3, 'clf__n_estimators': 50}
# Grid best score (recall):  0.9055555555555556
# recall score on holdout: 0.8
# SMOTE model training time: 0:00:48.599255
#
# -------- training GradientBoostingClassifier ----------
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 0.1, 'clf__loss': 'log_loss', 'clf__max_depth': 4, 'clf__n_estimators': 100}
# Grid best score (recall):  0.8138888888888889
# recall score on holdout: 0.6666666666666666
# model training time: 0:00:26.983262
#
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Grid best parameter (max. recall):  {'clf__learning_rate': 0.01, 'clf__loss': 'log_loss', 'clf__max_depth': 4, 'clf__n_estimators': 100}
# Grid best score (recall):  0.8861111111111111
# recall score on holdout: 0.7333333333333333
# SMOTE model training time: 0:00:30.549156
#
# -------- training XGBoostingClassifier ----------
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.1, 'clf__eval_metric': 'logloss', 'clf__gamma': 1, 'clf__max_depth': 4, 'clf__n_estimators': 50}
# Grid best score (recall):  0.8583333333333332
# recall score on holdout: 0.8
# model training time: 0:03:47.938120
#
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# Grid best parameter (max. recall):  {'clf__eta': 0.1, 'clf__eval_metric': 'logloss', 'clf__gamma': 1, 'clf__max_depth': 4, 'clf__n_estimators': 50}
# Grid best score (recall):  0.9083333333333332
# recall score on holdout: 0.8
# SMOTE model training time: 0:04:10.756413
#
#
# >>>>>> Begin model training for baldEagle E <<<<<<<<
# number of records in df: 547
# number of records in df after trade type E filtering: 29
# number of refused records in df: 2, 0.07%
# !! not enough refused samples to train !!
