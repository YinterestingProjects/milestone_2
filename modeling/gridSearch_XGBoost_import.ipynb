# %% [markdown]
# # Implementing gridsearchcv for XGBoost

# %%
import pandas as pd
import numpy as np
import modelinghelper as helper
import xgboost as xgb
import os
import joblib
# supress future warnings
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
#set up random seed
rng = 42

# set up folder to save results
output_path = 'gridsearch_all_models'
dataset = 'import'
mod_name = "XGBoost"
run_num = "run_1"

if not os.path.exists(output_path):
    os.makedirs(output_path)
else:
    print("Folder already exists")

# file name
prefix = f'{output_path}'
# Out:
# Folder already exists

# %%
# read in data
p = '../data/'
input_name = 'cleaned.csv'

df = pd.read_csv(f'{p}{input_name}')
# convert month to string
df['ship_date_mm'] = df['ship_date_mm'].astype(str)

# %%
non_feature_cols = ['control_number', 'disp_date', 'i_e', 'ship_date',
                    'cartons', 'qty', 'unit', 'specific_generic_name',
                    'genus', 'species', 'wildlf_cat',
                    'disp_date_yyyy', 'disp_date_mm', 'disp_ship_date']

target = ['act', 'dp_cd']

feature_cols = ['species_code', 'wildlf_desc', 'wildlf_cat',
                'ctry_org', 'ctry_ie','purp', 'src', 'trans_mode', 'pt_cd',
                'value', 'ship_date_mm']

import_df = helper.df_filtering(df, i_e = 'I', f_cols = feature_cols)

# %%
X_train, X_test, y_train, y_test = helper.data_split(import_df)

# %% [markdown]
# ### XGBoost

# %%
clf_xgb = xgb.XGBClassifier(random_state = rng, verbosity = 0, silent=True, use_label_encoder=False, tree_method="hist")

xgb_params = {
    'clf__n_estimators' : [100, 500, 1000],
    "clf__max_depth" : [1, 6,10,20,30,40],
    "clf__learning_rate" : np.linspace(.03, .3, 5),
    # used to prevent overfitting
    #"clf__subsample": [.75],
    #"clf__colsample_bylevel" : [.5,.6,.7],

     #early stopping?
}

xgb_pipe = helper.gridsearch_pipeline(X_train, y_train, clf_xgb, xgb_params)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=100;, score=0.212 total time=  13.3s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=100;, score=0.229 total time=  13.2s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=100;, score=0.215 total time=  13.0s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=100;, score=0.209 total time=  12.6s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=100;, score=0.215 total time=  12.5s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=500;, score=0.430 total time=  15.5s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=500;, score=0.426 total time=  15.9s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=500;, score=0.423 total time=  15.3s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=500;, score=0.419 total time=  15.6s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=500;, score=0.414 total time=  15.5s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=1000;, score=0.459 total time=  18.5s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=1000;, score=0.452 total time=  17.2s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=1000;, score=0.457 total time=  18.4s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=1000;, score=0.450 total time=  17.9s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=1000;, score=0.445 total time=  17.8s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=100;, score=0.512 total time=  13.7s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=100;, score=0.507 total time=  13.5s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=100;, score=0.507 total time=  14.1s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=100;, score=0.498 total time=  14.2s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=100;, score=0.491 total time=  13.8s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=500;, score=0.564 total time=  21.5s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=500;, score=0.558 total time=  21.2s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=500;, score=0.564 total time=  21.2s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=500;, score=0.552 total time=  21.4s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=500;, score=0.549 total time=  21.1s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=1000;, score=0.583 total time=  30.6s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=1000;, score=0.575 total time=  29.9s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=1000;, score=0.586 total time=  30.7s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=1000;, score=0.573 total time=  30.2s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=6, clf__n_estimators=1000;, score=0.569 total time=  30.7s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=100;, score=0.563 total time=  15.4s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=100;, score=0.561 total time=  15.2s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=100;, score=0.555 total time=  14.9s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=100;, score=0.551 total time=  15.1s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=100;, score=0.545 total time=  15.1s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=500;, score=0.597 total time=  28.4s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=500;, score=0.597 total time=  28.7s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=500;, score=0.602 total time=  27.9s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=500;, score=0.594 total time=  28.3s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=500;, score=0.584 total time=  28.3s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=1000;, score=0.625 total time=  43.1s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=1000;, score=0.615 total time=  43.5s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=1000;, score=0.621 total time=  43.2s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=1000;, score=0.618 total time=  43.5s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=1000;, score=0.606 total time=  43.3s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=100;, score=0.605 total time=  18.9s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=100;, score=0.604 total time=  18.7s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=100;, score=0.610 total time=  18.7s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=100;, score=0.600 total time=  18.7s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=100;, score=0.588 total time=  18.8s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=500;, score=0.637 total time=  44.0s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=500;, score=0.629 total time=  45.2s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=500;, score=0.630 total time=  45.3s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=500;, score=0.625 total time=  45.1s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=500;, score=0.610 total time=  44.6s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=1000;, score=0.647 total time= 1.2min
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=1000;, score=0.638 total time= 1.2min
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=1000;, score=0.640 total time= 1.2min
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=1000;, score=0.632 total time= 1.2min
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=20, clf__n_estimators=1000;, score=0.620 total time= 1.2min
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=100;, score=0.609 total time=  19.9s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=100;, score=0.605 total time=  19.5s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=100;, score=0.613 total time=  19.8s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=100;, score=0.602 total time=  19.6s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=100;, score=0.590 total time=  19.7s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=500;, score=0.641 total time=  54.2s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=500;, score=0.631 total time=  54.1s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=500;, score=0.635 total time=  55.0s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=500;, score=0.626 total time=  54.0s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=500;, score=0.615 total time=  55.0s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=1000;, score=0.646 total time= 1.5min
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=1000;, score=0.638 total time= 1.5min
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=1000;, score=0.643 total time= 1.5min
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=1000;, score=0.634 total time= 1.5min
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=30, clf__n_estimators=1000;, score=0.622 total time= 1.5min
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=100;, score=0.607 total time=  20.3s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=100;, score=0.604 total time=  19.6s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=100;, score=0.611 total time=  20.0s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=100;, score=0.602 total time=  20.1s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=100;, score=0.591 total time=  20.2s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=500;, score=0.640 total time=  58.6s
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=500;, score=0.636 total time=  59.6s
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=500;, score=0.638 total time=  58.9s
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=500;, score=0.625 total time=  58.6s
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=500;, score=0.615 total time=  59.2s
# [CV 1/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=1000;, score=0.648 total time= 1.6min
# [CV 2/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=1000;, score=0.640 total time= 1.6min
# [CV 3/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=1000;, score=0.646 total time= 1.6min
# [CV 4/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=1000;, score=0.633 total time= 1.6min
# [CV 5/5] END clf__learning_rate=0.03, clf__max_depth=40, clf__n_estimators=1000;, score=0.623 total time= 1.6min
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=100;, score=0.390 total time=  12.9s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=100;, score=0.395 total time=  12.9s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=100;, score=0.393 total time=  12.8s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=100;, score=0.383 total time=  13.0s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=100;, score=0.382 total time=  13.1s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=500;, score=0.470 total time=  15.8s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=500;, score=0.464 total time=  16.0s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=500;, score=0.468 total time=  16.0s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=500;, score=0.456 total time=  16.0s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=500;, score=0.455 total time=  15.8s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=1000;, score=0.483 total time=  18.4s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=1000;, score=0.475 total time=  18.9s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=1000;, score=0.478 total time=  19.1s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=1000;, score=0.466 total time=  19.7s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=1, clf__n_estimators=1000;, score=0.464 total time=  18.6s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=100;, score=0.546 total time=  14.1s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=100;, score=0.542 total time=  14.2s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=100;, score=0.545 total time=  14.4s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=100;, score=0.537 total time=  14.1s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=100;, score=0.522 total time=  14.2s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=500;, score=0.600 total time=  22.2s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=500;, score=0.590 total time=  21.9s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=500;, score=0.602 total time=  21.8s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=500;, score=0.591 total time=  21.9s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=500;, score=0.586 total time=  21.9s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=1000;, score=0.622 total time=  31.2s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=1000;, score=0.610 total time=  31.4s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=1000;, score=0.619 total time=  31.0s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=1000;, score=0.611 total time=  31.4s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=6, clf__n_estimators=1000;, score=0.602 total time=  30.9s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=100;, score=0.581 total time=  16.1s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=100;, score=0.578 total time=  16.0s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=100;, score=0.587 total time=  16.0s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=100;, score=0.577 total time=  16.0s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=100;, score=0.567 total time=  16.0s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=500;, score=0.639 total time=  28.6s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=500;, score=0.626 total time=  28.2s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=500;, score=0.636 total time=  28.2s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=500;, score=0.630 total time=  28.4s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=500;, score=0.609 total time=  28.2s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=1000;, score=0.650 total time=  43.0s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=1000;, score=0.636 total time=  43.2s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=1000;, score=0.647 total time=  43.0s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=1000;, score=0.636 total time=  43.0s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=10, clf__n_estimators=1000;, score=0.622 total time=  42.8s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=100;, score=0.630 total time=  20.0s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=100;, score=0.621 total time=  19.8s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=100;, score=0.626 total time=  19.9s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=100;, score=0.612 total time=  19.7s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=100;, score=0.602 total time=  19.8s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=500;, score=0.649 total time=  41.2s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=500;, score=0.640 total time=  41.6s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=500;, score=0.647 total time=  41.7s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=500;, score=0.639 total time=  41.3s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=500;, score=0.624 total time=  41.5s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=1000;, score=0.653 total time= 1.1min
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=1000;, score=0.643 total time= 1.1min
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=1000;, score=0.650 total time= 1.1min
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=1000;, score=0.639 total time= 1.1min
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=20, clf__n_estimators=1000;, score=0.627 total time= 1.1min
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=100;, score=0.637 total time=  21.5s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=100;, score=0.626 total time=  21.2s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=100;, score=0.629 total time=  21.4s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=100;, score=0.622 total time=  21.0s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=100;, score=0.607 total time=  21.1s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=500;, score=0.653 total time=  47.8s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=500;, score=0.642 total time=  48.0s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=500;, score=0.648 total time=  48.4s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=500;, score=0.637 total time=  47.7s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=500;, score=0.629 total time=  48.1s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=1000;, score=0.656 total time= 1.3min
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=1000;, score=0.644 total time= 1.3min
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=1000;, score=0.652 total time= 1.3min
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=1000;, score=0.640 total time= 1.3min
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=30, clf__n_estimators=1000;, score=0.630 total time= 1.3min
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=100;, score=0.639 total time=  21.7s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=100;, score=0.627 total time=  21.5s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=100;, score=0.633 total time=  21.4s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=100;, score=0.625 total time=  21.3s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=100;, score=0.611 total time=  21.4s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=500;, score=0.653 total time=  51.4s
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=500;, score=0.642 total time=  48.9s
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=500;, score=0.650 total time=  49.3s
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=500;, score=0.637 total time=  49.7s
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=500;, score=0.627 total time=  50.7s
# [CV 1/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=1000;, score=0.656 total time= 1.4min
# [CV 2/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=1000;, score=0.646 total time= 1.3min
# [CV 3/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=1000;, score=0.654 total time= 1.3min
# [CV 4/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=1000;, score=0.639 total time= 1.3min
# [CV 5/5] END clf__learning_rate=0.0975, clf__max_depth=40, clf__n_estimators=1000;, score=0.630 total time= 1.3min
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=100;, score=0.439 total time=  12.9s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=100;, score=0.437 total time=  12.8s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=100;, score=0.441 total time=  13.0s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=100;, score=0.433 total time=  13.1s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=100;, score=0.425 total time=  13.1s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=500;, score=0.482 total time=  15.4s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=500;, score=0.473 total time=  15.8s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=500;, score=0.476 total time=  15.9s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=500;, score=0.465 total time=  16.0s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=500;, score=0.461 total time=  16.0s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=1000;, score=0.488 total time=  18.5s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=1000;, score=0.480 total time=  18.7s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=1000;, score=0.483 total time=  18.8s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=1000;, score=0.475 total time=  18.1s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=1, clf__n_estimators=1000;, score=0.472 total time=  18.8s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=100;, score=0.566 total time=  14.1s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=100;, score=0.558 total time=  14.0s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=100;, score=0.565 total time=  14.1s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=100;, score=0.556 total time=  14.3s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=100;, score=0.556 total time=  14.1s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=500;, score=0.619 total time=  21.9s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=500;, score=0.603 total time=  21.5s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=500;, score=0.619 total time=  21.6s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=500;, score=0.602 total time=  21.7s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=500;, score=0.600 total time=  21.5s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=1000;, score=0.637 total time=  31.0s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=1000;, score=0.620 total time=  30.6s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=1000;, score=0.635 total time=  30.3s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=1000;, score=0.622 total time=  30.8s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=6, clf__n_estimators=1000;, score=0.615 total time=  30.4s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=100;, score=0.607 total time=  15.7s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=100;, score=0.603 total time=  15.7s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=100;, score=0.609 total time=  15.8s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=100;, score=0.598 total time=  15.8s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=100;, score=0.591 total time=  15.9s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=500;, score=0.651 total time=  28.0s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=500;, score=0.635 total time=  27.9s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=500;, score=0.642 total time=  27.6s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=500;, score=0.637 total time=  28.0s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=500;, score=0.622 total time=  27.8s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=1000;, score=0.659 total time=  41.9s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=1000;, score=0.640 total time=  42.4s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=1000;, score=0.654 total time=  41.8s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=1000;, score=0.643 total time=  42.0s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=10, clf__n_estimators=1000;, score=0.631 total time=  42.0s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=100;, score=0.639 total time=  19.2s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=100;, score=0.631 total time=  19.0s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=100;, score=0.633 total time=  19.2s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=100;, score=0.626 total time=  19.0s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=100;, score=0.613 total time=  19.0s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=500;, score=0.655 total time=  39.5s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=500;, score=0.644 total time=  39.4s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=500;, score=0.649 total time=  39.6s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=500;, score=0.636 total time=  39.2s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=500;, score=0.624 total time=  39.5s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=1000;, score=0.657 total time= 1.0min
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=1000;, score=0.644 total time= 1.0min
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=1000;, score=0.654 total time= 1.0min
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=1000;, score=0.640 total time= 1.0min
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=20, clf__n_estimators=1000;, score=0.627 total time= 1.0min
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=100;, score=0.643 total time=  20.9s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=100;, score=0.633 total time=  20.5s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=100;, score=0.637 total time=  20.5s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=100;, score=0.628 total time=  20.8s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=100;, score=0.616 total time=  20.3s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=500;, score=0.655 total time=  44.3s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=500;, score=0.644 total time=  44.5s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=500;, score=0.652 total time=  44.6s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=500;, score=0.642 total time=  45.4s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=500;, score=0.627 total time=  44.4s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=1000;, score=0.658 total time= 1.2min
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=1000;, score=0.646 total time= 1.2min
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=1000;, score=0.653 total time= 1.2min
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=1000;, score=0.644 total time= 1.2min
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=30, clf__n_estimators=1000;, score=0.629 total time= 1.2min
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=100;, score=0.644 total time=  21.7s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=100;, score=0.633 total time=  21.4s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=100;, score=0.641 total time=  21.1s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=100;, score=0.630 total time=  21.2s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=100;, score=0.617 total time=  21.3s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=500;, score=0.654 total time=  47.6s
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=500;, score=0.645 total time=  46.8s
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=500;, score=0.651 total time=  47.0s
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=500;, score=0.641 total time=  47.3s
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=500;, score=0.626 total time=  58.3s
# [CV 1/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=1000;, score=0.658 total time= 1.5min
# [CV 2/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=1000;, score=0.647 total time= 1.2min
# [CV 3/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=1000;, score=0.654 total time= 1.2min
# [CV 4/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=1000;, score=0.644 total time= 1.2min
# [CV 5/5] END clf__learning_rate=0.165, clf__max_depth=40, clf__n_estimators=1000;, score=0.629 total time= 1.3min
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=100;, score=0.455 total time=  12.9s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=100;, score=0.451 total time=  13.0s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=100;, score=0.455 total time=  13.1s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=100;, score=0.450 total time=  12.9s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=100;, score=0.442 total time=  12.8s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=500;, score=0.486 total time=  15.6s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=500;, score=0.477 total time=  15.1s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=500;, score=0.480 total time=  15.0s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=500;, score=0.471 total time=  15.0s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=500;, score=0.470 total time=  15.7s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=1000;, score=0.489 total time=  18.8s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=1000;, score=0.483 total time=  18.0s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=1000;, score=0.486 total time=  19.4s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=1000;, score=0.478 total time=  19.1s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=1, clf__n_estimators=1000;, score=0.476 total time=  19.0s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=100;, score=0.579 total time=  14.0s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=100;, score=0.571 total time=  14.0s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=100;, score=0.583 total time=  14.0s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=100;, score=0.568 total time=  14.0s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=100;, score=0.565 total time=  14.0s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=500;, score=0.628 total time=  22.4s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=500;, score=0.612 total time=  21.5s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=500;, score=0.622 total time=  21.5s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=500;, score=0.616 total time=  21.7s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=500;, score=0.605 total time=  21.6s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=1000;, score=0.643 total time=  31.1s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=1000;, score=0.627 total time=  30.9s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=1000;, score=0.641 total time=  30.5s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=1000;, score=0.630 total time=  31.1s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=6, clf__n_estimators=1000;, score=0.620 total time=  31.3s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=100;, score=0.619 total time=  16.0s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=100;, score=0.616 total time=  15.9s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=100;, score=0.620 total time=  15.8s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=100;, score=0.607 total time=  16.0s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=100;, score=0.604 total time=  15.9s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=500;, score=0.650 total time=  28.1s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=500;, score=0.640 total time=  28.2s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=500;, score=0.648 total time=  28.2s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=500;, score=0.639 total time=  27.9s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=500;, score=0.626 total time=  27.8s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=1000;, score=0.658 total time=  42.0s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=1000;, score=0.647 total time=  42.4s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=1000;, score=0.654 total time=  42.3s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=1000;, score=0.647 total time=  42.1s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=10, clf__n_estimators=1000;, score=0.631 total time=  42.1s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=100;, score=0.646 total time=  19.0s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=100;, score=0.635 total time=  18.8s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=100;, score=0.637 total time=  18.9s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=100;, score=0.628 total time=  19.1s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=100;, score=0.619 total time=  18.6s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=500;, score=0.656 total time=  38.8s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=500;, score=0.647 total time=  38.5s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=500;, score=0.652 total time=  38.6s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=500;, score=0.640 total time=  38.8s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=500;, score=0.631 total time=  38.2s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=1000;, score=0.658 total time= 1.0min
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=1000;, score=0.646 total time= 1.0min
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=1000;, score=0.653 total time= 1.0min
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=1000;, score=0.642 total time= 1.0min
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=20, clf__n_estimators=1000;, score=0.632 total time= 1.0min
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=100;, score=0.647 total time=  20.7s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=100;, score=0.635 total time=  20.2s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=100;, score=0.645 total time=  20.5s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=100;, score=0.632 total time=  20.5s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=100;, score=0.618 total time=  20.2s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=500;, score=0.655 total time=  43.4s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=500;, score=0.646 total time=  43.3s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=500;, score=0.652 total time=  43.1s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=500;, score=0.639 total time=  52.9s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=500;, score=0.628 total time=  45.8s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=1000;, score=0.657 total time= 1.2min
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=1000;, score=0.649 total time= 1.1min
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=1000;, score=0.654 total time= 1.1min
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=1000;, score=0.642 total time= 1.1min
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=30, clf__n_estimators=1000;, score=0.630 total time= 1.1min
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=100;, score=0.645 total time=  21.1s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=100;, score=0.640 total time=  20.9s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=100;, score=0.641 total time=  20.7s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=100;, score=0.635 total time=  20.9s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=100;, score=0.620 total time=  21.0s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=500;, score=0.654 total time=  44.9s
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=500;, score=0.647 total time=  45.6s
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=500;, score=0.652 total time=  45.3s
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=500;, score=0.642 total time=  45.6s
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=500;, score=0.627 total time=  44.8s
# [CV 1/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=1000;, score=0.657 total time= 1.2min
# [CV 2/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=1000;, score=0.650 total time= 1.2min
# [CV 3/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=1000;, score=0.653 total time= 1.2min
# [CV 4/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=1000;, score=0.643 total time= 1.2min
# [CV 5/5] END clf__learning_rate=0.2325, clf__max_depth=40, clf__n_estimators=1000;, score=0.631 total time= 1.2min
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=100;, score=0.463 total time=  12.9s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=100;, score=0.458 total time=  13.0s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=100;, score=0.463 total time=  13.2s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=100;, score=0.452 total time=  13.9s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=100;, score=0.448 total time=  13.5s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=500;, score=0.489 total time=  15.5s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=500;, score=0.481 total time=  15.8s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=500;, score=0.484 total time=  15.9s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=500;, score=0.473 total time=  16.0s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=500;, score=0.472 total time=  15.9s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=1000;, score=0.494 total time=  19.0s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=1000;, score=0.483 total time=  18.7s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=1000;, score=0.486 total time=  18.7s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=1000;, score=0.479 total time=  18.0s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=1, clf__n_estimators=1000;, score=0.478 total time=  18.8s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=100;, score=0.586 total time=  14.1s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=100;, score=0.580 total time=  14.0s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=100;, score=0.591 total time=  14.1s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=100;, score=0.577 total time=  14.0s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=100;, score=0.576 total time=  14.0s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=500;, score=0.634 total time=  21.9s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=500;, score=0.617 total time=  21.3s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=500;, score=0.632 total time=  21.6s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=500;, score=0.621 total time=  21.7s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=500;, score=0.612 total time=  21.7s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=1000;, score=0.648 total time=  30.8s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=1000;, score=0.629 total time=  30.5s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=1000;, score=0.647 total time=  31.0s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=1000;, score=0.633 total time=  30.9s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=6, clf__n_estimators=1000;, score=0.626 total time=  30.3s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=100;, score=0.630 total time=  15.9s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=100;, score=0.623 total time=  15.7s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=100;, score=0.629 total time=  15.7s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=100;, score=0.620 total time=  16.0s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=100;, score=0.607 total time=  15.7s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=500;, score=0.653 total time=  28.1s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=500;, score=0.639 total time=  28.2s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=500;, score=0.648 total time=  27.5s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=500;, score=0.641 total time=  27.9s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=500;, score=0.630 total time=  27.7s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=1000;, score=0.657 total time=  41.7s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=1000;, score=0.642 total time=  42.1s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=1000;, score=0.655 total time=  42.2s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=1000;, score=0.646 total time=  42.3s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=10, clf__n_estimators=1000;, score=0.634 total time=  41.9s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=100;, score=0.645 total time=  18.9s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=100;, score=0.637 total time=  18.6s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=100;, score=0.642 total time=  18.6s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=100;, score=0.632 total time=  19.1s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=100;, score=0.621 total time=  18.6s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=500;, score=0.655 total time=  38.0s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=500;, score=0.643 total time=  39.0s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=500;, score=0.652 total time=  39.6s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=500;, score=0.643 total time=  40.2s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=500;, score=0.628 total time=  39.2s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=1000;, score=0.658 total time= 1.0min
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=1000;, score=0.645 total time= 1.0min
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=1000;, score=0.657 total time= 1.0min
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=1000;, score=0.645 total time= 1.0min
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=20, clf__n_estimators=1000;, score=0.630 total time= 1.0min
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=100;, score=0.649 total time=  20.7s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=100;, score=0.640 total time=  20.3s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=100;, score=0.643 total time=  20.6s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=100;, score=0.633 total time=  20.4s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=100;, score=0.620 total time=  20.3s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=500;, score=0.658 total time=  43.9s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=500;, score=0.645 total time=  42.8s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=500;, score=0.654 total time=  43.2s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=500;, score=0.638 total time=  43.5s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=500;, score=0.627 total time=  42.9s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=1000;, score=0.662 total time= 1.2min
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=1000;, score=0.646 total time= 1.2min
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=1000;, score=0.657 total time= 1.2min
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=1000;, score=0.640 total time= 1.2min
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=30, clf__n_estimators=1000;, score=0.627 total time= 1.2min
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=100;, score=0.647 total time=  21.2s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=100;, score=0.638 total time=  20.9s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=100;, score=0.643 total time=  20.9s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=100;, score=0.634 total time=  21.2s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=100;, score=0.622 total time=  20.8s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=500;, score=0.655 total time=  45.4s
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=500;, score=0.645 total time=  44.9s
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=500;, score=0.651 total time=  46.7s
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=500;, score=0.637 total time=  45.4s
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=500;, score=0.633 total time=  45.4s
# [CV 1/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=1000;, score=0.660 total time= 1.2min
# [CV 2/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=1000;, score=0.647 total time= 1.2min
# [CV 3/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=1000;, score=0.654 total time= 1.2min
# [CV 4/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=1000;, score=0.639 total time= 1.2min
# [CV 5/5] END clf__learning_rate=0.3, clf__max_depth=40, clf__n_estimators=1000;, score=0.633 total time= 1.2min
# Grid best parameter (max. recall):  {'clf__learning_rate': 0.2325, 'clf__max_depth': 10, 'clf__n_estimators': 1000}
# Grid best score (recall):  0.6472964420733932

# %%
joblib.dump(xgb_pipe, f'{prefix}/xgb_pipe_import.joblib')
# Out:
# ['gridsearch_all_models/xgb_pipe_import.joblib']
