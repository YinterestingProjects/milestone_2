# %% [markdown]
# # Implementing gridsearchcv for LGBM SMOTE

# %%
import pandas as pd
import numpy as np
import modelinghelper as helper
import lightgbm as lgb
import os
import joblib
# supress future warnings
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %%
#set up random seed
rng = 42

# set up folder to save results
output_path = 'gridsearch_all_models'
dataset = 'import'
mod_name = "LGBM"
run_num = "run_1"

if not os.path.exists(output_path):
    os.makedirs(output_path)
else:
    print("Folder already exists")

# file name
prefix = f'{output_path}'
# Out:
# Folder already exists

# %%
# read in data
p = '../data/'
input_name = 'cleaned.csv'

df = pd.read_csv(f'{p}{input_name}')
# convert month to string
df['ship_date_mm'] = df['ship_date_mm'].astype(str)

# %%
non_feature_cols = ['control_number', 'disp_date', 'i_e', 'ship_date',
                    'cartons', 'qty', 'unit', 'specific_generic_name',
                    'genus', 'species', 'wildlf_cat',
                    'disp_date_yyyy', 'disp_date_mm', 'disp_ship_date']

target = ['act', 'dp_cd']

feature_cols = ['species_code', 'wildlf_desc', 'wildlf_cat',
                'ctry_org', 'ctry_ie','purp', 'src', 'trans_mode', 'pt_cd',
                'value', 'ship_date_mm']

export_df = helper.df_filtering(df, i_e = 'I', f_cols = feature_cols)

# %%
X_train, X_test, y_train, y_test = helper.data_split(export_df)

# %% [markdown]
# ### LGBM

# %%
clf_lgbm = lgb.LGBMClassifier(random_state=rng)

lgbm_params = {
    'clf__n_estimators' : [100, 500, 1000],
    "clf__max_depth" : [5,10,15,20,-1],
    "clf__num_leaves" : [10,20,30,50,70],
    "clf__learning_rate" : [.05,.1],
     #early stopping?
}

lgbm_pipe = helper.gridsearch_pipeline(X_train, y_train, clf_lgbm, lgbm_params)
# Out:
# Fitting 5 folds for each of 3360 candidates, totalling 16800 fits
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=2;, score=0.548 total time=   2.4s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=2;, score=0.587 total time=   2.1s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=2;, score=0.590 total time=   2.4s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=2;, score=0.562 total time=   2.2s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=2;, score=0.554 total time=   2.2s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=5;, score=0.548 total time=   2.4s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=5;, score=0.587 total time=   2.2s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=5;, score=0.590 total time=   2.2s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=5;, score=0.562 total time=   2.4s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=5;, score=0.554 total time=   2.1s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=10;, score=0.548 total time=   2.1s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=10;, score=0.587 total time=   2.4s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=10;, score=0.590 total time=   2.1s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=10;, score=0.562 total time=   2.1s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=10;, score=0.554 total time=   2.5s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=15;, score=0.548 total time=   2.1s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=15;, score=0.587 total time=   2.2s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=15;, score=0.590 total time=   2.5s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators=50, clf__num_leaves=15;, score=0.562 total time=   2.2s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=1, clf__n_estimators

# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=20;, score=0.597 total time=   2.3s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=20;, score=0.660 total time=   2.5s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=20;, score=0.657 total time=   2.4s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=20;, score=0.627 total time=   2.3s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=20;, score=0.632 total time=   2.5s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=25;, score=0.595 total time=   2.4s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=25;, score=0.665 total time=   2.3s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=25;, score=0.662 total time=   2.6s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=25;, score=0.624 total time=   2.4s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=25;, score=0.627 total time=   2.3s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=30;, score=0.600 total time=   2.6s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=30;, score=0.660 total time=   2.3s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=30;, score=0.655 total time=   2.3s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=30;, score=0.627 total time=   2.5s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=30;, score=0.630 total time=   2.3s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=35;, score=0.605 total time=   2.4s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=35;, score=0.655 total time=   2.5s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=35;, score=0.636 total time=   2.3s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=35;, score=0.622 total time=   2.5s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=5, clf__n_estimators=150, clf__num_leaves=35;, score=0.627 total time=   2.4s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=2;, score=0.548 total time=   2.1s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=2;, score=0.587 total time=   2.4s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=2;, score=0.590 total time=   2.1s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=2;, score=0.562 total time=   2.1s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=2;, score=0.554 total time=   2.3s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=5;, score=0.556 total time=   2.3s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=5;, score=0.621 total time=   2.1s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=5;, score=0.649 total time=   2.1s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=5;, score=0.596 total time=   2.1s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=5;, score=0.606 total time=   2.1s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=10;, score=0.579 total time=   2.2s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=10;, score=0.647 total time=   2.2s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=10;, score=0.652 total time=   2.1s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=10;, score=0.627 total time=   2.2s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=10;, score=0.624 total time=   2.3s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=15;, score=0.600 total time=   2.1s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=15;, score=0.670 total time=   2.2s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=15;, score=0.683 total time=   2.3s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=15;, score=0.624 total time=   2.1s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=15;, score=0.630 total time=   2.2s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=20;, score=0.600 total time=   2.4s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=20;, score=0.662 total time=   2.1s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=20;, score=0.670 total time=   2.2s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=20;, score=0.622 total time=   2.4s
# [CV 5/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=20;, score=0.632 total time=   2.1s
# [CV 1/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=25;, score=0.608 total time=   2.3s
# [CV 2/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=25;, score=0.657 total time=   2.3s
# [CV 3/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators=50, clf__num_leaves=25;, score=0.675 total time=   2.1s
# [CV 4/5] END clf__class_weight=balanced, clf__learning_rate=0.03, clf__max_depth=10, clf__n_estimators