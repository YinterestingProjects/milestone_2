# %%
#Import statements
import pandas as pd
import numpy as np
import re
import joblib
import os

# %%
codes_df = pd.read_csv('Lemis Data/key_2016.csv', encoding='ISO-8859-1')

# %%
import_path = 'Lemis Data/Imports 05-16/'
export_path = 'Lemis Data/Exports 05-16/'
imports = [f for f in os.listdir(import_path)]
exports = [f for f in os.listdir(export_path)]
lemis_imports_dict = {}
lemis_exports_dict = {}

for file in imports:
    year = re.findall(r'\d+', file)[0]
    import_df = pd.read_csv(f'{import_path}{file}', encoding='ISO-8859-1')
    lemis_imports_dict[file] = import_df
    
for file in exports:
    year = re.findall(r'\d+', file)[0]
    export_df = pd.read_csv(f'{export_path}{file}', encoding='ISO-8859-1')
    lemis_exports_dict[file] = export_df
    
lemis_import = pd.concat(lemis_imports_dict.values(), ignore_index=True)
lemis_export = pd.concat(lemis_exports_dict.values(), ignore_index=True)

# %%
#Shape
print(lemis_import.shape)
#Columns
lemis_import.columns
# Out:
# (4590303, 23)
# Index(['Unnamed: 0', 'Species\r\r\nCode', 'Genus', 'Species', 'Sub Species',
#        'Specific\r\r\nName', 'Generic\r\r\nName', 'Wildlf\r\r\nDesc', 'Unit',
#        '# of Cartons', 'Ctry\r\r\nOrg', 'Ctry\r\r\nIE', 'Purp', 'Src', 'Act',
#        'Dp\r\r\nCd', 'Disp\r\r\nDate', 'Ship\r\r\nDate', 'IE', 'Pt\r\r\nCd',
#        'Trans Mode', 'U.S.Importer/\r\r\nExporter', 'X__1'],
#       dtype='object')

# %%
#Shape
print(lemis_export.shape)
#Columns
lemis_export.columns
# Out:
# (942690, 23)
# Index(['Unnamed: 0', 'Species\r\r\nCode', 'Genus', 'Species', 'Sub Species',
#        'Specific\r\r\nName', 'Generic\r\r\nName', 'Wildlf\r\r\nDesc', 'Unit',
#        '# of Cartons', 'Ctry\r\r\nOrg', 'Ctry\r\r\nIE', 'Purp', 'Src', 'Act',
#        'Dp\r\r\nCd', 'Disp\r\r\nDate', 'Ship\r\r\nDate', 'IE', 'Pt\r\r\nCd',
#        'Trans Mode', 'U.S.Importer/\r\r\nExporter', 'X__1'],
#       dtype='object')

# %%
def CleanDataFrameColumns(dataframe):
    
    df = dataframe.copy()
    column_mapping = {'wildlf_desc': 'description', '# of cartons': 'measure_value', 'ctry_org': 'country_origin',
                      'ctry_ie': 'country_import_export', 'purp': 'purpose', 'src': 'source',
                      'act': 'action', 'dp_cd': 'disposition', 'disp_date': 'disposition_date', 
                      'ship_date': 'shipment_date', 'ie': 'import_export', 'pt_cd': 'port', 
                      'trans mode': 'transport_mode', 'u.s.importer/_exporter': 'us_co', 'sub species': 'sub_species'}
    drop_cols = ['Unnamed: 0', 'X__1']
    df = df.drop(columns=drop_cols)
    df.columns = df.columns.str.replace('\r', ' ')
    df.columns = df.columns.str.replace(r'\n',  '', regex=True)
    df.columns = df.columns.str.replace('  ', '_')
    df.columns = df.columns.str.lower()
    df = df.rename(columns=column_mapping) 
    
    df = df.replace(r'[*]+', np.nan, regex=True)
    df['unit'] = df['unit'].str.upper()    
    df['country_origin'] = df['country_origin'].str.upper()
    df['country_origin'] = df['country_origin'].fillna('XX')
    df['country_import_export'] = df['country_import_export'].str.upper()
    df['country_import_export'] = df['country_import_export'].fillna('XX')
    
    return df

# %%
lemis_import_cleaned = CleanDataFrameColumns(lemis_import)
lemis_export_cleaned = CleanDataFrameColumns(lemis_export)

# %%
lemis_import_cleaned.head()
# Out:
#   species_code      genus    species sub_species specific_name generic_name  \
# 0         PCMR   PINCTADA  MARTENSII         NaN           NaN       OYSTER
# 1         PHAC  PHASIANUS  COLCHICUS         NaN        COMMON     PHEASANT
# 2         MACR   MACROPUS      RUFUS         NaN           RED     KANGAROO
# 3         MACR   MACROPUS      RUFUS         NaN           RED     KANGAROO
# 4         ANGJ   ANGUILLA   JAPONICA         NaN      JAPANESE          EEL
#
#   description unit  measure_value country_origin  ... purpose source action  \
# 0         SHE   NO        12397.0             JP  ...       T      W      C
# 1         MEA   KG          350.0             CA  ...       T      C      C
# 2         SHO   NO           76.0             AU  ...       T      W      C
# 3         SHO   NO           70.0             AU  ...       T      W      C
# 4         LIV   KG            7.0             CN  ...       T      C      C
#
#   disposition disposition_date shipment_date import_export port  \
# 0           C       2004-12-29    2005-01-02             I   SF
# 1           C       2004-12-30    2005-01-03             I   PH
# 2           C       2004-12-30    2005-01-02             I   SE
# 3           C       2004-12-30    2005-01-02             I   SE
# 4           C       2004-12-31    2005-01-01             I   SP
#
#   transport_mode                               us_co
# 0              O                 KORET OF CALIFORNIA
# 1              T          VAN VOOREN GAME RANCH INC.
# 2              O                      CABELA'S, INC.
# 3              O                      CABELA'S, INC.
# 4              A  TIANSHUN LOGISTICS SERVICES CO LTD
#
# [5 rows x 21 columns]

# %%
lemis_export_cleaned.head()
# Out:
#   species_code              genus       species sub_species specific_name  \
# 0          NaN            STASINA       SAETOSA         NaN           NaN
# 1          NaN            STASINA      MACLEAYI         NaN           NaN
# 2          NaN            STASINA        LUCASI         NaN           NaN
# 3          NaN        SPARIANTHUS  SELENOPOIDES         NaN           NaN
# 4          NaN  PSEUDOSPARIANTHUS        CUBANA         NaN           NaN
#
#   generic_name description unit  measure_value country_origin  ... purpose  \
# 0          NaN         SPE   NO            1.0             DO  ...       S
# 1          NaN         SPE   NO            1.0             CU  ...       S
# 2          NaN         SPE   NO            1.0             CU  ...       S
# 3          NaN         SPE   NO            1.0             PA  ...       S
# 4          NaN         SPE   NO            1.0             CU  ...       S
#
#   source action disposition disposition_date shipment_date import_export port  \
# 0      W      C           C       2004-12-16    2005-01-05             E   BO
# 1      W      C           C       2004-12-16    2005-01-05             E   BO
# 2      W      C           C       2004-12-16    2005-01-05             E   BO
# 3      W      C           C       2004-12-16    2005-01-05             E   BO
# 4      W      C           C       2004-12-16    2005-01-05             E   BO
#
#   transport_mode                                              us_co
# 0              A  Museum of Comparative Zoology, Harvard University
# 1              A  Museum of Comparative Zoology, Harvard University
# 2              A  Museum of Comparative Zoology, Harvard University
# 3              A  Museum of Comparative Zoology, Harvard University
# 4              A  Museum of Comparative Zoology, Harvard University
#
# [5 rows x 21 columns]

# %%
lemis_import_cleaned['disposition_date'] = lemis_import_cleaned['disposition_date'].replace('NA', '1/1/2999')
lemis_import_cleaned['shipment_date'] = lemis_import_cleaned['shipment_date'].replace('NA', '1/1/2999')
lemis_import_cleaned[lemis_import_cleaned.columns[~lemis_import_cleaned.columns.isin(['country_origin','country_import_export'])]] = lemis_import_cleaned[lemis_import_cleaned.columns[~lemis_import_cleaned.columns.isin(['country_origin','country_import_export'])]].replace('NA', '')  

lemis_export_cleaned['disposition_date'] = lemis_export_cleaned['disposition_date'].replace('NA', '1/1/2999')
lemis_export_cleaned['shipment_date'] = lemis_export_cleaned['shipment_date'].replace('NA', '1/1/2999')
lemis_export_cleaned[lemis_export_cleaned.columns[~lemis_export_cleaned.columns.isin(['country_origin','country_import_export'])]] = lemis_export_cleaned[lemis_export_cleaned.columns[~lemis_export_cleaned.columns.isin(['country_origin','country_import_export'])]].replace('NA', '')

# %%
#Function to create a dataframe for each column in codes to join on
def createCodeDataframe(col, new_name):
    df = codes_df[codes_df['field'] == col].rename(columns={'value': new_name})
    return df

# Looping through the code dataframes to join onto the main lemis import and export df
codes_list = ['action', 'description', 'disposition', 'port', 'purpose', 'source', 'unit', 'transport_mode']
for code in codes_list:
    
    code_df = createCodeDataframe(code, f'{code}_value')
    if code=='unit':
        code_df['code'] = code_df['code'].str.upper()   
    
    lemis_import_cleaned = lemis_import_cleaned.set_index(code)
    lemis_export_cleaned = lemis_export_cleaned.set_index(code)
    
    code_df = code_df.set_index('code').drop(columns='field')
    
    lemis_import_cleaned = lemis_import_cleaned.join(code_df, how='left')
    lemis_export_cleaned = lemis_export_cleaned.join(code_df, how='left')

country_origin_df = createCodeDataframe('country', 'country_origin_value')
country_origin_df['code'] = country_origin_df['code'].str.upper()
country_origin_df = country_origin_df.set_index('code').drop(columns='field')

lemis_import_cleaned = lemis_import_cleaned.set_index('country_origin')
lemis_import_cleaned = lemis_import_cleaned.join(country_origin_df, how='left')
lemis_export_cleaned = lemis_export_cleaned.set_index('country_origin')
lemis_export_cleaned = lemis_export_cleaned.join(country_origin_df, how='left')

country_import_export_df = createCodeDataframe('country', 'country_import_export_value')
country_import_export_df = country_import_export_df.set_index('code').drop(columns='field')

lemis_import_cleaned = lemis_import_cleaned.set_index('country_import_export')
lemis_import_cleaned = lemis_import_cleaned.join(country_import_export_df, how='left')
lemis_export_cleaned = lemis_export_cleaned.set_index('country_import_export')
lemis_export_cleaned = lemis_export_cleaned.join(country_import_export_df, how='left')

lemis_import_cleaned = lemis_import_cleaned.reset_index(drop=True)
lemis_export_cleaned = lemis_export_cleaned.reset_index(drop=True)

# %%
lemis_import_cleaned.head()
# Out:
#   species_code     genus     species sub_species specific_name generic_name  \
# 0         ELKK    CERVUS     ELAPHUS         NaN           NaN          ELK
# 1         CEDA      DAMA        DAMA         NaN        FALLOW         DEER
# 2         OVAR      OVIS       ARIES         NaN      DOMESTIC        SHEEP
# 3         ANCE  ANTILOPE  CERVICAPRA         NaN           NaN    BLACKBUCK
# 4         CEAX      AXIS        AXIS         NaN           NaN       CHITAL
#
#    measure_value disposition_date shipment_date import_export  ...  \
# 0            1.0       2012-12-11    2012-12-02             I  ...
# 1            1.0       2012-12-11    2012-12-02             I  ...
# 2            1.0       2012-12-11    2012-12-02             I  ...
# 3            1.0       2012-12-11    2012-12-02             I  ...
# 4            1.0       2012-12-11    2012-12-02             I  ...
#
#   action_value                     description_value disposition_value  \
# 0      Cleared  Trophy (all the parts of one animal)           Cleared
# 1      Cleared  Trophy (all the parts of one animal)           Cleared
# 2      Cleared  Trophy (all the parts of one animal)           Cleared
# 3      Cleared  Trophy (all the parts of one animal)           Cleared
# 4      Cleared  Trophy (all the parts of one animal)           Cleared
#
#   port_value     purpose_value                   source_value  \
# 0    Atlanta  Hunting Trophies  Specimens taken from the wild
# 1    Atlanta  Hunting Trophies  Specimens taken from the wild
# 2    Atlanta  Hunting Trophies  Specimens taken from the wild
# 3    Atlanta  Hunting Trophies  Specimens taken from the wild
# 4    Atlanta  Hunting Trophies  Specimens taken from the wild
#
#             unit_value transport_mode_value country_origin_value  \
# 0  Number of Specimens            Air cargo            Argentina
# 1  Number of Specimens            Air cargo            Argentina
# 2  Number of Specimens            Air cargo            Argentina
# 3  Number of Specimens            Air cargo            Argentina
# 4  Number of Specimens            Air cargo            Argentina
#
#   country_import_export_value
# 0                     Andorra
# 1                     Andorra
# 2                     Andorra
# 3                     Andorra
# 4                     Andorra
#
# [5 rows x 21 columns]

# %%
lemis_import_cleaned.shape, lemis_export_cleaned.shape
# Out:
# ((5553659, 21), (1300882, 21))

# %%
lemis = lemis_import_cleaned.append(lemis_export_cleaned, ignore_index=True)

# %%
lemis.shape
# Out:
# (6854541, 21)

# %%
lemis.columns
# Out:
# Index(['species_code', 'genus', 'species', 'sub_species', 'specific_name',
#        'generic_name', 'measure_value', 'disposition_date', 'shipment_date',
#        'import_export', 'us_co', 'action_value', 'description_value',
#        'disposition_value', 'port_value', 'purpose_value', 'source_value',
#        'unit_value', 'transport_mode_value', 'country_origin_value',
#        'country_import_export_value'],
#       dtype='object')

# %%
lemis.dtypes
# Out:
# species_code                    object
# genus                           object
# species                         object
# sub_species                     object
# specific_name                   object
# generic_name                    object
# measure_value                  float64
# disposition_date                object
# shipment_date                   object
# import_export                   object
# us_co                           object
# action_value                    object
# description_value               object
# disposition_value               object
# port_value                      object
# purpose_value                   object
# source_value                    object
# unit_value                      object
# transport_mode_value            object
# country_origin_value            object
# country_import_export_value     object
# dtype: object

# %%
lemis.isna().sum()
# Out:
# species_code                     84543
# genus                           347313
# species                         643761
# sub_species                    6614675
# specific_name                  2339709
# generic_name                    425426
# measure_value                  1263580
# disposition_date                     0
# shipment_date                        0
# import_export                        0
# us_co                             3342
# action_value                         0
# description_value                  773
# disposition_value                   79
# port_value                          75
# purpose_value                      986
# source_value                      4047
# unit_value                       12242
# transport_mode_value            473354
# country_origin_value              1397
# country_import_export_value       9859
# dtype: int64

# %%
#Creating label for if any of these columns are known or not and fixing nulls
for col in ['genus', 'species_code', 'species', 'sub_species', 'specific_name', 'generic_name', 'us_co', 'action_value',
            'description_value', 'disposition_value', 'port_value', 'purpose_value', 'source_value', 'unit_value', 'transport_mode_value']:
    lemis[col] = np.where(lemis[col].isna(), f'unknown_{col}', lemis[col])
    
lemis['measure_value'] = lemis['measure_value'].fillna(999999)

# %%
lemis['disposition_date'] = lemis['disposition_date'].str.replace('/', '-')
lemis['shipment_date'] = lemis['shipment_date'].str.replace('/', '-')
lemis[['disposition_date','shipment_date']] = lemis[['disposition_date','shipment_date']].apply(pd.to_datetime)

# %%
lemis.head()
# Out:
#   species_code     genus     species          sub_species  \
# 0         ELKK    CERVUS     ELAPHUS  unknown_sub_species
# 1         CEDA      DAMA        DAMA  unknown_sub_species
# 2         OVAR      OVIS       ARIES  unknown_sub_species
# 3         ANCE  ANTILOPE  CERVICAPRA  unknown_sub_species
# 4         CEAX      AXIS        AXIS  unknown_sub_species
#
#            specific_name generic_name  measure_value disposition_date  \
# 0  unknown_specific_name          ELK            1.0       2012-12-11
# 1                 FALLOW         DEER            1.0       2012-12-11
# 2               DOMESTIC        SHEEP            1.0       2012-12-11
# 3  unknown_specific_name    BLACKBUCK            1.0       2012-12-11
# 4  unknown_specific_name       CHITAL            1.0       2012-12-11
#
#   shipment_date import_export  ... action_value  \
# 0    2012-12-02             I  ...      Cleared
# 1    2012-12-02             I  ...      Cleared
# 2    2012-12-02             I  ...      Cleared
# 3    2012-12-02             I  ...      Cleared
# 4    2012-12-02             I  ...      Cleared
#
#                       description_value disposition_value port_value  \
# 0  Trophy (all the parts of one animal)           Cleared    Atlanta
# 1  Trophy (all the parts of one animal)           Cleared    Atlanta
# 2  Trophy (all the parts of one animal)           Cleared    Atlanta
# 3  Trophy (all the parts of one animal)           Cleared    Atlanta
# 4  Trophy (all the parts of one animal)           Cleared    Atlanta
#
#       purpose_value                   source_value           unit_value  \
# 0  Hunting Trophies  Specimens taken from the wild  Number of Specimens
# 1  Hunting Trophies  Specimens taken from the wild  Number of Specimens
# 2  Hunting Trophies  Specimens taken from the wild  Number of Specimens
# 3  Hunting Trophies  Specimens taken from the wild  Number of Specimens
# 4  Hunting Trophies  Specimens taken from the wild  Number of Specimens
#
#   transport_mode_value country_origin_value country_import_export_value
# 0            Air cargo            Argentina                     Andorra
# 1            Air cargo            Argentina                     Andorra
# 2            Air cargo            Argentina                     Andorra
# 3            Air cargo            Argentina                     Andorra
# 4            Air cargo            Argentina                     Andorra
#
# [5 rows x 21 columns]

# %%
lemis.isna().sum()
# Out:
# species_code                      0
# genus                             0
# species                           0
# sub_species                       0
# specific_name                     0
# generic_name                      0
# measure_value                     0
# disposition_date                  0
# shipment_date                     0
# import_export                     0
# us_co                             0
# action_value                      0
# description_value                 0
# disposition_value                 0
# port_value                        0
# purpose_value                     0
# source_value                      0
# unit_value                        0
# transport_mode_value              0
# country_origin_value           1397
# country_import_export_value    9859
# dtype: int64

# %%
lemis['unit_value'].value_counts()
# Out:
# Number of Specimens    6421568
# Kilograms               331077
# Milliliters              48246
# Grams                    35900
# unknown_unit_value       12242
# Square Meters             1742
# Milligrams                1356
# Liters                    1294
# Meters                     553
# Centimeters                280
# Cubic Centimeters          149
# Square Centimeter           74
# Cubic Meters                60
# Name: unit_value, dtype: int64

# %%
lemis['species'].value_counts()
# Out:
# SPECIES               708912
# unknown_species       643761
# MAXIMA                304179
# MISSISSIPPIENSIS      212869
# NILOTICUS             170417
#                        ...
# ANOLIS GARMANI             1
# ANOLIS VALENCIENNI         1
# ANOLIS GRAHAMI             1
# PRAESIGNIS                 1
# HEEMSTRAORUM               1
# Name: species, Length: 16740, dtype: int64

# %%
lemis['generic_name'].value_counts()
# Out:
# CORAL                   618014
# OYSTER                  463247
# unknown_generic_name    425426
# SHELL                   323163
# ALLIGATOR               212878
#                          ...
# JEWFISH                      1
# OLIVEBACK                    1
# MUSTARD                      1
# PAINTBRUSH                   1
# PIKEPERCH                    1
# Name: generic_name, Length: 2253, dtype: int64

# %%
cols_index = ['species_code', 'genus', 'species', 'sub_species', 
             'specific_name', 'generic_name', 'disposition_date', 
             'shipment_date', 'import_export', 'transport_mode_value', 
             'us_co', 'action_value', 'description_value', 
             'disposition_value', 'port_value', 'purpose_value', 
             'source_value', 'country_origin_value', 'country_import_export_value']
lemis_pivot = lemis.pivot_table(index=cols_index, columns='unit_value', values='measure_value').reset_index()
lemis_pivot.columns = lemis_pivot.columns.str.replace(' ', '_')
lemis_pivot.columns = lemis_pivot.columns.str.lower()
lemis_pivot.columns.name = None

measure_value_cols = ['centimeters', 'cubic_centimeters', 'cubic_meters', 'grams', 'kilograms', 
                      'liters', 'meters', 'milligrams', 'milliliters', 'number_of_specimens', 
                      'square_centimeter', 'square_meters', 'unknown_unit_value']

lemis_pivot[measure_value_cols] = lemis_pivot[measure_value_cols].replace(999999, np.nan)

# %%
lemis_pivot.head(20)
# Out:
#    species_code    genus  species          sub_species          specific_name  \
# 0          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 1          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 2          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 3          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 4          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 5          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 6          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 7          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 8          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 9          AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 10         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 11         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 12         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 13         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 14         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 15         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 16         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 17         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 18         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
# 19         AAA?  ASTRAEA  SPECIES  unknown_sub_species  unknown_specific_name
#
#    generic_name disposition_date shipment_date import_export  \
# 0         SHELL       2005-01-13    2005-01-05             I
# 1         SHELL       2005-01-18    2005-01-18             E
# 2         SHELL       2005-01-26    2005-01-12             I
# 3         SHELL       2005-01-26    2005-01-17             I
# 4         SHELL       2005-02-15    2005-02-15             E
# 5         SHELL       2005-03-11    2005-03-11             E
# 6         SHELL       2005-03-18    2005-03-15             I
# 7         SHELL       2005-03-18    2005-03-15             I
# 8         SHELL       2005-03-31    2005-03-31             E
# 9         SHELL       2005-04-12    2005-04-08             E
# 10        SHELL       2005-04-12    2005-04-08             E
# 11        SHELL       2005-04-29    2005-04-29             I
# 12        SHELL       2005-05-06    2005-05-06             I
# 13        SHELL       2005-05-10    2005-05-10             I
# 14        SHELL       2005-05-13    2005-05-13             E
# 15        SHELL       2005-06-07    2005-06-07             E
# 16        SHELL       2005-06-17    2005-05-17             I
# 17        SHELL       2005-06-22    2005-06-03             I
# 18        SHELL       2005-06-22    2005-06-22             E
# 19        SHELL       2005-07-21    2005-07-21             E
#
#                    transport_mode_value  ... grams kilograms liters meters  \
# 0          unknown_transport_mode_value  ...   NaN       NaN    NaN    NaN
# 1                      Personal vehicle  ...   NaN       NaN    NaN    NaN
# 2          unknown_transport_mode_value  ...   NaN       NaN    NaN    NaN
# 3          unknown_transport_mode_value  ...   NaN       NaN    NaN    NaN
# 4                      Personal vehicle  ...   NaN       NaN    NaN    NaN
# 5                      Personal vehicle  ...   NaN       NaN    NaN    NaN
# 6          unknown_transport_mode_value  ...   NaN       NaN    NaN    NaN
# 7          unknown_transport_mode_value  ...   NaN       NaN    NaN    NaN
# 8                      Personal vehicle  ...   NaN       NaN    NaN    NaN
# 9                                  Mail  ...   NaN       NaN    NaN    NaN
# 10                                 Mail  ...   NaN       NaN    NaN    NaN
# 11  Truck (or other commercial vehicle)  ...   NaN       NaN    NaN    NaN
# 12  Truck (or other commercial vehicle)  ...   NaN       NaN    NaN    NaN
# 13  Truck (or other commercial vehicle)  ...   NaN       NaN    NaN    NaN
# 14                     Personal vehicle  ...   NaN       NaN    NaN    NaN
# 15                     Personal vehicle  ...   NaN       NaN    NaN    NaN
# 16         unknown_transport_mode_value  ...   NaN       NaN    NaN    NaN
# 17         unknown_transport_mode_value  ...   NaN       NaN    NaN    NaN
# 18                     Personal vehicle  ...   NaN       NaN    NaN    NaN
# 19                     Personal vehicle  ...   NaN       NaN    NaN    NaN
#
#    milligrams milliliters number_of_specimens square_centimeter square_meters  \
# 0         NaN         NaN              1157.0               NaN           NaN
# 1         NaN         NaN                 NaN               NaN           NaN
# 2         NaN         NaN                 NaN               NaN           NaN
# 3         NaN         NaN                 NaN               NaN           NaN
# 4         NaN         NaN                 NaN               NaN           NaN
# 5         NaN         NaN                 NaN               NaN           NaN
# 6         NaN         NaN                15.0               NaN           NaN
# 7         NaN         NaN                15.0               NaN           NaN
# 8         NaN         NaN                 NaN               NaN           NaN
# 9         NaN         NaN                 1.0               NaN           NaN
# 10        NaN         NaN                 1.0               NaN           NaN
# 11        NaN         NaN                 NaN               NaN           NaN
# 12        NaN         NaN                 NaN               NaN           NaN
# 13        NaN         NaN                 NaN               NaN           NaN
# 14        NaN         NaN                 NaN               NaN           NaN
# 15        NaN         NaN                 2.0               NaN           NaN
# 16        NaN         NaN                 NaN               NaN           NaN
# 17        NaN         NaN                30.0               NaN           NaN
# 18        NaN         NaN                 3.0               NaN           NaN
# 19        NaN         NaN                10.0               NaN           NaN
#
#     unknown_unit_value
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
#
# [20 rows x 32 columns]

# %%
lemis_pivot.isna().sum()
# Out:
# species_code                         0
# genus                                0
# species                              0
# sub_species                          0
# specific_name                        0
# generic_name                         0
# disposition_date                     0
# shipment_date                        0
# import_export                        0
# transport_mode_value                 0
# us_co                                0
# action_value                         0
# description_value                    0
# disposition_value                    0
# port_value                           0
# purpose_value                        0
# source_value                         0
# country_origin_value                 0
# country_import_export_value          0
# centimeters                    5569385
# cubic_centimeters              5569600
# cubic_meters                   5569583
# grams                          5544479
# kilograms                      5328366
# liters                         5568655
# meters                         5569167
# milligrams                     5568558
# milliliters                    5540049
# number_of_specimens            1188590
# square_centimeter              5569579
# square_meters                  5568241
# unknown_unit_value             5569160
# dtype: int64

# %%
lemis_pivot.shape
# Out:
# (5569636, 32)

# %%
lemis_pivot.to_csv('lemis_imports_exports.csv')
